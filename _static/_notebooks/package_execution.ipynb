# %% [markdown]
# # Package Execution Quick Start
#
# This notebook runs the complete Sephora experiment pipeline.

# %%
from sephora_test.run_experiments import config, run_experiments

# %% [markdown]
# ## Run experiment

# %%
results = run_experiments(
    experiment_config=config,
)

# %% [markdown]
# ## Available results

# %%
results.keys()

# %% [markdown]
# ## Processed training dataset

# %%
results["train_processed"].head()

# %% [markdown]
# ## Nature code metrics

# %%
results["nature_metrics"]

# %% [markdown]
# ## Target code metrics

# %%
results["target_metrics"]

# %% [markdown]
# ## Processed test dataset

# %%
results["test_processed"].head()
